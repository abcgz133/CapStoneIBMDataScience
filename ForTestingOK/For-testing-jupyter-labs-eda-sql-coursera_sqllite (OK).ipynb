# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork865-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9
# from sqlalchemy import create_engine

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql

# %%
#import csv, sqlite3

#con = sqlite3.connect("my_data1.db")
# cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5

# %%
# %sql sqlite:///my_data1.db
# from sqlalchemy import create_engine

# %%
# !pip install ipython-sql
# %load_ext sql

# %%
import csv, sqlite3

# %%
# %sql mysql+pymysql://root:root@localhost/heima

# %%
# %%sql
# select * from tb_hotel
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 201 rows affected.
# [(36934, '7天连锁酒店(上海宝山路地铁站店)', '静安交通路40号', 336, 37, '7天酒店', '上海', '二钻', '四川北路商业区', '31.251433', '121.47522', 'https://m.tuniucdn.com/fb2/t1/G1/M00/3E/40/Cii9EVkyLrKIXo1vAAHgrxo_pUcAALcKQLD688AAeDH564_w200_h200_c1_t0.jpg'),
#  (38609, '速8酒店(上海赤峰路店)', '广灵二路126号', 249, 35, '速8', '上海', '二钻', '四川北路商业区', '31.282444', '121.479385', 'https://m.tuniucdn.com/fb2/t1/G2/M00/DF/96/Cii-TFkx0ImIQZeiAAITil0LM7cAALCYwKXHQ4AAhOi377_w200_h200_c1_t0.jpg'),
#  (38665, '速8酒店上海中山北路兰田路店', '兰田路38号', 226, 35, '速8', '上海', '二钻', '长风公园地区', '31.244288', '121.422419', 'https://m.tuniucdn.com/fb2/t1/G2/M00/EF/86/Cii-Tlk2mV2IMZ-_AAEucgG3dx4AALaawEjiycAAS6K083_w200_h200_c1_t0.jpg'),
#  (38812, '7天连锁酒店(上海漕溪路地铁站店)', '徐汇龙华西路315弄58号', 298, 37, '7天酒店', '上海', '二钻', '八万人体育场地区', '31.174377', '121.442875', 'https://m.tuniucdn.com/fb2/t1/G2/M00/E0/0E/Cii-TlkyIr2IEWNoAAHQYv7i5CkAALD-QP2iJwAAdB6245_w200_h200_c1_t0.jpg'),
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.head()
df['Mission_Outcome'] = df['Mission_Outcome'].apply(lambda x : x.strip())

# %%
df.head(3)
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  04-06-2010   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  08-12-2010   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  22-05-2012   07:44:00  F9 v1.0  B0005  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
#
#        Orbit         Customer Mission_Outcome     Landing _Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# 2  LEO (ISS)      NASA (COTS)         Success           No attempt

# %%
df.columns
# Out:
# Index(['Date', 'Time (UTC)', 'Booster_Version', 'Launch_Site', 'Payload',
#        'PAYLOAD_MASS__KG_', 'Orbit', 'Customer', 'Mission_Outcome',
#        'Landing _Outcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (101, 10)

# %%
df
# Out:
#            Date Time (UTC) Booster_Version   Launch_Site  \
# 0    04-06-2010   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1    08-12-2010   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2    22-05-2012   07:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3    08-10-2012   00:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4    01-03-2013   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# ..          ...        ...             ...           ...
# 96   05-11-2020   23:24:23    F9 B5B1062.1  CCAFS SLC-40
# 97   16-11-2020   00:27:00   F9 B5B1061.1     KSC LC-39A
# 98   21-11-2020   17:17:08    F9 B5B1063.1   VAFB SLC-4E
# 99   25-11-2020   02:13:00  F9 B5 B1049.7   CCAFS SLC-40
# 100  06-12-2020   16:17:08  F9 B5 B1058.4     KSC LC-39A
#
#                                                Payload  PAYLOAD_MASS__KG_  \
# 0                 Dragon Spacecraft Qualification Unit                  0
# 1    Dragon demo flight C1, two CubeSats, barrel of...                  0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Date', 'Time (UTC)', 'Booster_Version', 'Launch_Site', 'Payload',
#        'PAYLOAD_MASS__KG_', 'Orbit', 'Customer', 'Mission_Outcome',
#        'Landing _Outcome'],
#       dtype='object')

# %%
df.rename(columns = {"Landing _Outcome":"Landing_Outcome"}, inplace = True)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#df = df.rename(columns = {'Booster_Version', 'Booster_Version'}, inplace = True)

# %%
df
# Out:
#            Date Time (UTC) Booster_Version   Launch_Site  \
# 0    04-06-2010   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1    08-12-2010   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2    22-05-2012   07:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3    08-10-2012   00:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4    01-03-2013   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# ..          ...        ...             ...           ...
# 96   05-11-2020   23:24:23    F9 B5B1062.1  CCAFS SLC-40
# 97   16-11-2020   00:27:00   F9 B5B1061.1     KSC LC-39A
# 98   21-11-2020   17:17:08    F9 B5B1063.1   VAFB SLC-4E
# 99   25-11-2020   02:13:00  F9 B5 B1049.7   CCAFS SLC-40
# 100  06-12-2020   16:17:08  F9 B5 B1058.4     KSC LC-39A
#
#                                                Payload  PAYLOAD_MASS__KG_  \
# 0                 Dragon Spacecraft Qualification Unit                  0
# 1    Dragon demo flight C1, two CubeSats, barrel of...                  0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Landing _Outcome
# df.rename(columns = {"Landing _Outcome", "Landing_Outcome"}, inplace = True)

# %%
df.columns
# Out:
# Index(['Date', 'Time (UTC)', 'Booster_Version', 'Launch_Site', 'Payload',
#        'PAYLOAD_MASS__KG_', 'Orbit', 'Customer', 'Mission_Outcome',
#        'Landing_Outcome'],
#       dtype='object')

# %%
df.head(3)
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  04-06-2010   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  08-12-2010   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  22-05-2012   07:44:00  F9 v1.0  B0005  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# 2  LEO (ISS)      NASA (COTS)         Success           No attempt

# %%
# !pip install sqlalchemy
from sqlalchemy import create_engine

# %%
# %%sql
# drop table spacextbl;
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 0 rows affected.
# []

# %%
# con = sqlite3.connect("heima.db")
# %sql mysql+pymysql://root:root@localhost/heima
# engine = create_engine('postgresql+psycopg2://scott:tiger@localhost/mydatabase')

conn=create_engine('mysql+pymysql://root:root@localhost/heima')

# %%
# %%sql
# select * from spacextbl;
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# (pymysql.err.ProgrammingError) (1146, "Table 'heima.spacextbl' doesn't exist")
# [SQL: select * from spacextbl;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
df.to_sql("SPACEXTBL", conn, if_exists='replace', index=False,method="multi")
# Out:
# C:\Users\ABCGZ\anaconda3\lib\site-packages\pandas\io\sql.py:1666: UserWarning: The provided table name 'SPACEXTBL' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# 101

# %%
# %%sql
# select * from spacextbl;
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 101 rows affected.
# [('04-06-2010', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('08-12-2010', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('22-05-2012', '07:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('08-10-2012', '00:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('01-03-2013', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('29-09-2013', '16:00:00', 'F9 v1.1  B1003', 'VAFB SLC-4E', 'CASSIOPE', 500, 'Polar LEO', 'MDA', 'Success', 'Uncontrolled (ocean)'),
# ...

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# df

# %%
# df.dtypes

# %%
# %%sql
# select distinct Launch_Site from Spacextbl;
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 4 rows affected.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %%
# df[(df['Mission_Outcome'] != 'Success')]

# %%
# %%sql
# select Mission_Outcome, Landing_Outcome, count(*)  from SPACEXTBL group by "Mission_Outcome", "Landing_Outcome"
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 1 rows affected.
# [('Success', 'Failure (parachute)', 101)]

# %%
# %%sql
# select count(*)  from SPACEXTBL
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 1 rows affected.
# [(101,)]

# %%
# %sql select *  from SPACEXTBL where Customer like "NASA (CRS)"

# %%
# df.tail()

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %%sql
# select * from spacextbl where Launch_Site like "CCA%" limit 5
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 5 rows affected.
# [('04-06-2010', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('08-12-2010', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('22-05-2012', '07:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('08-10-2012', '00:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('01-03-2013', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %%
# %%sql
# select * from spacextbl where Launch_Site like "CCA%" limit 5
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 5 rows affected.
# [('04-06-2010', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('08-12-2010', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('22-05-2012', '07:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('08-10-2012', '00:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('01-03-2013', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %%sql
# select sum(PAYLOAD_MASS__KG_) total_payload from spacextbl where  Customer like "NASA (CRS)";
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 1 rows affected.
# [(Decimal('45596'),)]

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %%sql
# select Round(AVG(PAYLOAD_MASS__KG_),2)  total_payload from spacextbl where Booster_Version like  "F9 v1.1%"
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 1 rows affected.
# [(Decimal('2534.67'),)]

# %%
# %sql select *  from spacextbl where Booster_Version like  "F9 v1.1%"

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# df.dtypes

# %%
# %%sql
# select *  , Date   from spacextbl where "Landing _Outcome" like "Success (ground pad)%"
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 0 rows affected.
# []

# %%
# %%sql
# select Landing_Outcome , Min(Date), *    from spacextbl where "Landing_Outcome" like "Success (ground pad)%"
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# (pymysql.err.ProgrammingError) (1064, 'You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near \'*    from spacextbl where "Landing_Outcome" like "Success (ground pad)%"\' at line 1')
# [SQL: select Landing_Outcome , Min(Date), *    from spacextbl where "Landing_Outcome" like "Success (ground pad)%%"]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# select  min(Date) , landing_outcome   from spacextbl  where landing_outcome like "Success (ground pad)%"
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 1 rows affected.
# [('01-05-2017', 'Success (ground pad)')]

# %%
# %%sql
# select MIN(Date)  from spacextbl
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 1 rows affected.
# [('01-03-2013',)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %%sql
# select Booster_Version, PAYLOAD_MASS__KG_   from spacextbl where Landing_Outcome like "Success (ground pad)%" and PAYLOAD_MASS__KG_ > 4000
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 3 rows affected.
# [('F9 FT B1032.1', 5300), ('F9 B4 B1040.1', 4990), ('F9 B4 B1043.1', 5000)]

# %%
# %%sql
# select Booster_Version   from spacextbl where Landing_Outcome like "Success (ground pad)%" and (PAYLOAD_MASS__KG_ > 4000 and PAYLOAD_MASS__KG_ < 6000)
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 3 rows affected.
# [('F9 FT B1032.1',), ('F9 B4 B1040.1',), ('F9 B4 B1043.1',)]

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %sql select *   from spacextbl where Mission_Outcome !=  "Success"

# %%
# %sql select count(*) ,  Mission_outcome   from spacextbl group by Mission_Outcome
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 3 rows affected.
# [(1, 'Failure (in flight)'),
#  (99, 'Success'),
#  (1, 'Success (payload status unclear)')]

# %%
# %sql select "Mission_Outcome", Landing_Outcome, count(*)  from SPACEXTBL group by "Mission_Outcome", "Landing_Outcome"
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 11 rows affected.
# [('Failure (in flight)', 'Precluded (drone ship)', 1),
#  ('Success', 'Controlled (ocean)', 5),
#  ('Success', 'Failure', 3),
#  ('Success', 'Failure (drone ship)', 5),
#  ('Success', 'Failure (parachute)', 2),
#  ('Success', 'No attempt', 22),
#  ('Success', 'Success', 38),
#  ('Success', 'Success (drone ship)', 14),
#  ('Success', 'Success (ground pad)', 8),
#  ('Success', 'Uncontrolled (ocean)', 2),
#  ('Success (payload status unclear)', 'Success (ground pad)', 1)]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
# %sql select  Booster_Version, PAYLOAD_MASS__KG_ from spacextbl where PAYLOAD_MASS__KG_ =  \
(select max(PAYLOAD_MASS__KG_) max_payload from spacextbl limit 1)
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 12 rows affected.
# [('F9 B5 B1048.4', 15600),
#  ('F9 B5 B1049.4', 15600),
#  ('F9 B5 B1051.3', 15600),
#  ('F9 B5 B1056.4', 15600),
#  ('F9 B5 B1048.5', 15600),
#  ('F9 B5 B1051.4', 15600),
#  ('F9 B5 B1049.5', 15600),
#  ('F9 B5 B1060.2 ', 15600),
#  ('F9 B5 B1058.3 ', 15600),
#  ('F9 B5 B1051.6', 15600),
#  ('F9 B5 B1060.3', 15600),
#  ('F9 B5 B1049.7 ', 15600)]

# %%
#

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 4, 2) as month to get the months and substr(Date,7,4)='2015' for year.**

# %%
# %%sql
# select substr(date, 7,4) year, substr(date, 4,2) month , Landing_Outcome , Booster_Version, Launch_site
# from spacextbl where Landing_Outcome =  "Failure (drone ship)"
# and substr(date, 7,4 ) = "2015"
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 2 rows affected.
# [('2015', '01', 'Failure (drone ship)', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  ('2015', '04', 'Failure (drone ship)', 'F9 v1.1 B1015', 'CCAFS LC-40')]

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the  count of  successful landing_outcomes between the date 04-06-2010 and 20-03-2017 in descending order.

# %%
# According the staff's oppinion : 
# Only Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20

# %%
# %%sql
# SELECT Landing_Outcome,count("Landing_Outcome") as LANDING_OUTCOME_COUNT, DATE
# from SPACEXTBL where
# substr(Date,7,4) || substr(Date,4,2) || substr(Date,1,2) between '20100604' and '20170320'
# group by Landing_Outcome
# order by LANDING_OUTCOME_COUNT DESC
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 10 rows affected.
# [('Success', 38, '22-07-2018'),
#  ('No attempt', 22, '22-05-2012'),
#  ('Success (drone ship)', 14, '08-04-2016'),
#  ('Success (ground pad)', 9, '22-12-2015'),
#  ('Controlled (ocean)', 5, '18-04-2014'),
#  ('Failure (drone ship)', 5, '10-01-2015'),
#  ('Failure', 3, '05-12-2018'),
#  ('Failure (parachute)', 2, '04-06-2010'),
#  ('Uncontrolled (ocean)', 2, '29-09-2013'),
#  ('Precluded (drone ship)', 1, '28-06-2015')]

# %%
# %%sql
# SELECT Landing_Outcome,count(Landing_Outcome) as LANDING_COUNT, DATE
# from SPACEXTBL where
# substr(Date,7,4) || substr(Date,4,2) || substr(Date,1,2) between '20100604' and '20170320'
# and (Landing_Outcome like "Success%" or Landing_Outcome like "Controlled%" )
# group by Landing_Outcome
# order by LANDING_COUNT desc
# Out:
#  * mysql+pymysql://root:***@localhost/heima
# 10 rows affected.
# [('Success', 38, '22-07-2018'),
#  ('No attempt', 22, '22-05-2012'),
#  ('Success (drone ship)', 14, '08-04-2016'),
#  ('Success (ground pad)', 9, '22-12-2015'),
#  ('Controlled (ocean)', 5, '18-04-2014'),
#  ('Failure (drone ship)', 5, '10-01-2015'),
#  ('Failure', 3, '05-12-2018'),
#  ('Failure (parachute)', 2, '04-06-2010'),
#  ('Uncontrolled (ocean)', 2, '29-09-2013'),
#  ('Precluded (drone ship)', 1, '28-06-2015')]

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
